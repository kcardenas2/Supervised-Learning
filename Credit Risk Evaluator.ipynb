# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
#check DATA
train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
# ...

# %%
#check DATA
test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1       25429  25429     6000.0    0.1524       208.70           RENT
# 2       38496  38496     3600.0    0.1695       128.27           RENT
# 3       19667  19667    20000.0    0.1524       478.33           RENT
# 4       37505  37505     3600.0    0.1240       120.27           RENT
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    140000.0        Not Verified    low_risk          n  ...            97.7
# 1     55000.0        Not Verified    low_risk          n  ...            66.7
# 2     42000.0        Not Verified    low_risk          n  ...           100.0
# 3    100000.0        Not Verified    low_risk          n  ...           100.0
# 4     50000.0        Not Verified    low_risk          n  ...           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# ...

# %%
#My predicition between logistic regression and random forest would be random forest would work best 
#because the data provided is bigger and better to handle in random forest than logestic regression and potentially
#has more outliers.

# %%
# Convert categorical data to numeric and separate target feature for training data
train_df_1 = train_df.drop("loan_status", axis=1)
X_train = pd.get_dummies(train_df_1, dtype=float)

y_train = LabelEncoder().fit_transform(train_df['loan_status'])

# %%
# Convert categorical data to numeric and separate target feature for testing data
test_df_1 = test_df.drop("loan_status", axis=1)
X_test = pd.get_dummies(test_df_1, dtype=float)

y_test = LabelEncoder().fit_transform(test_df['loan_status'])

# %%
# add missing dummy variables to testing set
X = test_df.drop('income', axis=1)
X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-61c5a5f4dddb> in <module>
#       1 # add missing dummy variables to testing set
# ----> 2 X = test_df.drop('income', axis=1)
#       3 X
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
classifier_lr = LogisticRegression().fit(X_train, y_train)

print(f"Training Data Score: {classifier_lr.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier_lr.score(X_test, y_test)}")

# %%
# Train a Random Forest Classifier model and print the model score
classifier_rf = RandomForestClassifier(random_state=1, n_estimators=300).fit(X_train, y_train)

print(f"Training Data Score: {classifier_rf.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier_rf.score(X_test, y_test)}")

# %%
# Scale the data
scaler = StandardScaler().fit(X_selected_train)
X_selected_train_scaled = scaler.transform(X_train)
X_selected_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
LR_scaled = LogisticRegression()

LR_scaled.fit(X_selected_train_scaled, y_train)

print(f"Training Data Score: {LR_scaled.score(X_selected_train_scaled, y_train)}")
print(f"Testing Data Score: {LR_scaled.score(X_selected_test_scaled, y_test)}")

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
